# %%
1600*0.001
# Out:
# 1.6

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Ruta de los archivos .npy
url = './'

# Pedir al usuario el nombre del archivo
archivo = 'no_separator_no_current_nodes_f600_dt_f0.001_layer_n_2_11_0.npy'

# Construir la ruta del archivo
ruta = os.path.join(url, archivo)

# Verificar si el archivo existe
if os.path.isfile(ruta) and archivo.endswith('.npy'):
    # Cargar los datos del archivo .npy
    data = np.load(ruta)
    ultimo_nodo = data[:, 1600]

    # Obtener el valor máximo y su posición
    valor = ultimo_nodo.max()
    print(f"Valor máximo: {valor}")
    min_valor = ultimo_nodo.min()
    print(f"Valor mínimo: {min_valor}")

    # Generar el tiempo en el eje x
    tiempo = np.arange(len(ultimo_nodo)) / 600

    # Crear la figura y el subplot
    fig, ax = plt.subplots(figsize=(12, 5))

    # Graficar los datos
    ax.plot(tiempo, ultimo_nodo, color='black', label=f'Tiempo = 1.6 us')  # tiempo en el eje x
    ax.set_title('Transmitted and Reflected Amplitude (Cathode - Anode)', fontsize=16)
    ax.set_xlabel('Length (mm)', fontsize=14)
    ax.set_ylabel('Amplitude', fontsize=14)
    ax.axvline(x=tiempo[len(tiempo)//2], linestyle='--', color='gray', linewidth=1.5)
    ax.legend(loc='best', fontsize=12)

    # Ajustar diseño y mostrar gráfico
    plt.tight_layout()
    plt.show()

else:
    print("El archivo no existe o no es un archivo .npy válido. Verifique el nombre e intente nuevamente.")
# Out:
# Valor máximo: 0.36311600545653006
# Valor mínimo: -0.4908411554382325

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Ruta de los archivos .npy
url = './'

# Pedir al usuario el nombre del archivo
archivo = 'no_separator_no_current_nodes_f600_dt_f0.001_layer_n_2_2_11.npy'

# Construir la ruta del archivo
ruta = os.path.join(url, archivo)

# Verificar si el archivo existe
if os.path.isfile(ruta) and archivo.endswith('.npy'):
    # Cargar los datos del archivo .npy
    data = np.load(ruta)
    ultimo_nodo = data[:, 2000]

    # Obtener el valor máximo y su posición
    valor = ultimo_nodo.max()
    print(f"Valor máximo: {valor}")
    min_valor = ultimo_nodo.min()
    print(f"Valor mínimo: {min_valor}")

    # Generar el tiempo en el eje x
    tiempo = np.arange(len(ultimo_nodo)) / 600

    # Crear la figura y el subplot
    fig, ax = plt.subplots(figsize=(12, 5))

    # Graficar los datos
    ax.plot(tiempo, ultimo_nodo, color='black', label=f'Tiempo = 2 us')  # tiempo en el eje x
    ax.set_title('Transmitted and Reflected Amplitude (Anode - Cathode)', fontsize=16)
    ax.set_xlabel('Length (mm)', fontsize=14)
    ax.set_ylabel('Amplitude', fontsize=14)
    ax.axvline(x=tiempo[len(tiempo)//2], linestyle='--', color='gray', linewidth=1.5)
    ax.legend(loc='best', fontsize=12)

    # Ajustar diseño y mostrar gráfico
    plt.tight_layout()
    plt.show()

else:
    print("El archivo no existe o no es un archivo .npy válido. Verifique el nombre e intente nuevamente.")
# Out:
# Valor máximo: 0.996726805081355
# Valor mínimo: -0.7335956660388118
